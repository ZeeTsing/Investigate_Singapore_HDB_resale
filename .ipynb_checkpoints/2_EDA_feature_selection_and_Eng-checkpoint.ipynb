# %%
import numpy as np
import pandas as pd
import seaborn as sns
import datetime
import matplotlib.pyplot as plt
import scipy.stats as stats

# %% [markdown]
# First we need to import the dataset and select which columns to keep

# %%
data = pd.read_pickle('df_final_cleaned.pkl')

# %%
data.columns
# Out:
# Index(['month', 'town', 'flat_type', 'block', 'street_name', 'storey_range',
#        'floor_area_sqm', 'flat_model', 'lease_commence_date',
#        'remaining_lease', 'resale_price', 'Postal_code', 'postal_code',
#        'num_schools', 'school_rank_nearby', 'Year', 'Month', 'low', 'high',
#        'storey', 'Remaining_years_y', 'Remaining_months', 'Remaining_years',
#        'Remaining_lease_years'],
#       dtype='object')

# %%
columns_to_keep = ['month','Year','Month','town','flat_type','storey','floor_area_sqm','flat_model','Remaining_lease_years','Postal_code','num_schools',"school_rank_nearby",'resale_price']

# %%
df = pd.DataFrame(data[columns_to_keep])

# %%
df.head()
# Out:
#      month  Year Month        town flat_type  storey  floor_area_sqm  \
# 0  2017-01  2017    01  ANG MO KIO    2 ROOM      11            44.0
# 1  2017-01  2017    01  ANG MO KIO    3 ROOM       2            67.0
# 2  2017-01  2017    01  ANG MO KIO    3 ROOM       2            67.0
# 3  2017-01  2017    01  ANG MO KIO    3 ROOM       5            68.0
# 4  2017-01  2017    01  ANG MO KIO    3 ROOM       2            67.0
#
#        flat_model  Remaining_lease_years Postal_code  num_schools  \
# 0        Improved              61.333333      560406         11.0
# 1  New Generation              60.583333      560108          8.0
# 2  New Generation              62.416667      560602          4.0
# 3  New Generation              62.083333      560465         10.0
# 4  New Generation              62.416667      560601          4.0
#
#    school_rank_nearby  resale_price
# 0                   0      232000.0
# 1                   0      250000.0
# 2                   0      262000.0
# 3                   0      265000.0
# 4                   0      265000.0

# %%
df.describe()
# Out:
#              storey  floor_area_sqm  Remaining_lease_years   num_schools  \
# count  62410.000000    62410.000000           62410.000000  62410.000000
# mean       8.619372       97.823086              74.537168      8.972472
# std        5.744786       24.286204              12.420809      3.555794
# min        2.000000       31.000000              46.083333      1.000000
# 25%        5.000000       82.000000              65.166667      7.000000
# 50%        8.000000       95.000000              74.500000      9.000000
# 75%       11.000000      113.000000              83.416667     11.000000
# max       50.000000      249.000000              96.666667     20.000000
#
#        school_rank_nearby  resale_price
# count          62410.0000  6.241000e+04
# mean               0.7585  4.391509e+05
# std                0.7591  1.540182e+05
# min                0.0000  1.500000e+05
# 25%                0.0000  3.300000e+05
# 50%                1.0000  4.070000e+05
# 75%                1.0000  5.120000e+05
# max                3.0000  1.205000e+06

# %% [markdown]
# Most of our features are categorical, we would like to do some simple exploration and grouping where possible

# %%
def Count (series):
    keys = series.unique()
    count_dict = dict.fromkeys(keys,0)

    for item in series:
        count_dict[item] += 1
    return count_dict

# %%
flat_type_count = Count(df.flat_type)

# %%
flat_type_count
# Out:
# {'2 ROOM': 885,
#  '3 ROOM': 15117,
#  '4 ROOM': 25803,
#  '5 ROOM': 15483,
#  'EXECUTIVE': 5060,
#  '1 ROOM': 29,
#  'MULTI-GENERATION': 33}

# %% [markdown]
# We will group 1 room and 2 room as one category as both entries are of little value. Similarly for multi-gen and executive flats

# %%
def redefine_type (flat):
    if flat == "2 ROOM" or flat == "1 ROOM":
        return "1 / 2 ROOM"
    elif flat == "EXECUTIVE" or flat == 'MULTI-GENERATION':
        return 'EXECUTIVE & MULTI-GENERATION'
    else: return flat

# %%
df['flat_type'] = df.flat_type.apply(lambda x: redefine_type(x))

# %%
model_type_count = Count(df.flat_model)

# %%
model_type_count
# Out:
# {'Improved': 15630,
#  'New Generation': 8782,
#  'DBSS': 907,
#  'Standard': 1752,
#  'Apartment': 2554,
#  'Simplified': 2677,
#  'Model A': 20070,
#  'Premium Apartment': 6792,
#  'Adjoined flat': 114,
#  'Model A-Maisonette': 106,
#  'Maisonette': 1877,
#  'Type S1': 114,
#  'Type S2': 62,
#  'Model A2': 876,
#  'Terrace': 38,
#  'Improved-Maisonette': 13,
#  'Premium Maisonette': 7,
#  'Multi Generation': 33,
#  'Premium Apartment Loft': 6}

# %%
def redefine_model (flat):
    if flat == 'Model A-Maisonette' or flat == 'Improved-Maisonette' or flat == 'Premium Maisonette':
        return 'Maisonette'
    elif flat == 'Premium Apartment' or flat == 'Premium Apartment Loft':
        return 'Apartment'
    elif flat == 'Terrace' or flat == 'Multi Generation' or flat =='Adjoined flat':
        return "Terrace/Multi-Gen/Adjoined"
    elif flat == 'Model A2':
        return "Model A"
    elif flat == 'Type S1' or flat == 'Type S2':
        return "Type S"
    else: return flat

# %%
df['flat_model'] = df.flat_model.apply(lambda x: redefine_model(x))

# %%
model_type_count = Count(df.flat_model)
model_type_count
# Out:
# {'Improved': 15630,
#  'New Generation': 8782,
#  'DBSS': 907,
#  'Standard': 1752,
#  'Apartment': 9352,
#  'Simplified': 2677,
#  'Model A': 20946,
#  'Terrace/Multi-Gen/Adjoined': 185,
#  'Maisonette': 2003,
#  'Type S': 176}

# %%
town_count = Count(df.town)

# %%
town_count
# Out:
# {'ANG MO KIO': 2809,
#  'BEDOK': 3348,
#  'BISHAN': 1233,
#  'BUKIT BATOK': 2394,
#  'BUKIT MERAH': 2516,
#  'BUKIT PANJANG': 2262,
#  'BUKIT TIMAH': 184,
#  'CENTRAL AREA': 525,
#  'CHOA CHU KANG': 2627,
#  'CLEMENTI': 1374,
#  'GEYLANG': 1520,
#  'HOUGANG': 2904,
#  'JURONG EAST': 1401,
#  'JURONG WEST': 4812,
#  'KALLANG/WHAMPOA': 1866,
#  'MARINE PARADE': 372,
#  'PASIR RIS': 1775,
#  'PUNGGOL': 3888,
#  'QUEENSTOWN': 1670,
#  'SEMBAWANG': 1763,
#  'SENGKANG': 4835,
#  'SERANGOON': 1292,
#  'TAMPINES': 3963,
#  'TOA PAYOH': 2124,
#  'WOODLANDS': 4850,
#  'YISHUN': 4151}

# %% [markdown]
# We may consider to drop this variable as model type may implied the floor area and could be corelated with flat_type as well

# %%
columns_to_plot = ['storey','floor_area_sqm','Remaining_lease_years','num_schools',"school_rank_nearby",'resale_price']
sns.pairplot(df[columns_to_plot])

# %%
df.corr()
# Out:
#                          storey  floor_area_sqm  Remaining_lease_years  \
# storey                 1.000000        0.019081               0.279905
# floor_area_sqm         0.019081        1.000000               0.221270
# Remaining_lease_years  0.279905        0.221270               1.000000
# num_schools           -0.059488        0.099638               0.314682
# school_rank_nearby     0.058915        0.002712               0.297797
# resale_price           0.374200        0.632863               0.327372
#
#                        num_schools  school_rank_nearby  resale_price
# storey                   -0.059488            0.058915      0.374200
# floor_area_sqm            0.099638            0.002712      0.632863
# Remaining_lease_years     0.314682            0.297797      0.327372
# num_schools               1.000000            0.144722     -0.040443
# school_rank_nearby        0.144722            1.000000     -0.114782
# resale_price             -0.040443           -0.114782      1.000000

# %% [markdown]
# We note the price distribution is right skewed > consider to transform if needed
#
# Floor_area is a little bit skewed. need further test to confirm;
#
# Storey can be transformed into categorical variable and so does school rank nearby

# %%
df.month  = pd.to_datetime(df.month)

# %%
df.sample(6)
# Out:
#            month  Year Month             town flat_type  storey  \
# 28016 2018-05-01  2018    05        WOODLANDS    5 ROOM       8
# 15976 2017-10-01  2017    10  KALLANG/WHAMPOA    3 ROOM      11
# 48257 2019-04-01  2019    04        WOODLANDS    4 ROOM      11
# 17958 2017-11-01  2017    11          PUNGGOL    4 ROOM      11
# 39155 2018-11-01  2018    11     CENTRAL AREA    4 ROOM      26
# 26967 2018-05-01  2018    05          HOUGANG    4 ROOM       8
#
#        floor_area_sqm  flat_model  Remaining_lease_years Postal_code  \
# 28016           120.0    Improved              81.250000      730539
# 15976            68.0    Improved              53.250000      330034
# 48257            89.0  Simplified              73.750000      730321
# 17958            94.0     Model A              95.416667      823624
# 39155            87.0    Improved              64.333333      052335
# 26967            84.0  Simplified              68.000000      530512
#
#        num_schools  school_rank_nearby  resale_price
# 28016         10.0                   1      438000.0
# 15976          6.0                   2      360000.0
# 48257          7.0                   2      310000.0
# 17958         14.0                   2      436000.0
# 39155          4.0                   0      668000.0
# 26967         11.0                   0      362000.0

# %%
df.storey.plot.box()

# %%
df.storey.describe()
# Out:
# count    62410.000000
# mean         8.619372
# std          5.744786
# min          2.000000
# 25%          5.000000
# 50%          8.000000
# 75%         11.000000
# max         50.000000
# Name: storey, dtype: float64

# %%
def redefine_storey (storey):
    if 1< storey <= 7:
        return "0_LowFlr"
    elif storey <= 11:
        return "1_MediumFlr"
    else: return "2_HighFlr"

# %%
df['storey'] = df.storey.apply(lambda x: redefine_storey(x))

# %%
df.head()
# Out:
#        month  Year Month        town   flat_type       storey  floor_area_sqm  \
# 0 2017-01-01  2017    01  ANG MO KIO  1 / 2 ROOM  1_MediumFlr            44.0
# 1 2017-01-01  2017    01  ANG MO KIO      3 ROOM     0_LowFlr            67.0
# 2 2017-01-01  2017    01  ANG MO KIO      3 ROOM     0_LowFlr            67.0
# 3 2017-01-01  2017    01  ANG MO KIO      3 ROOM     0_LowFlr            68.0
# 4 2017-01-01  2017    01  ANG MO KIO      3 ROOM     0_LowFlr            67.0
#
#        flat_model  Remaining_lease_years Postal_code  num_schools  \
# 0        Improved              61.333333      560406         11.0
# 1  New Generation              60.583333      560108          8.0
# 2  New Generation              62.416667      560602          4.0
# 3  New Generation              62.083333      560465         10.0
# 4  New Generation              62.416667      560601          4.0
#
#    school_rank_nearby  resale_price
# 0                   0      232000.0
# 1                   0      250000.0
# 2                   0      262000.0
# 3                   0      265000.0
# 4                   0      265000.0

# %%
categorical_features = ['Month','town','flat_type','storey','school_rank_nearby',"flat_model"]

for column in categorical_features:
    category = list(df[column].unique())
    cat_dtype = pd.api.types.CategoricalDtype(categories=category)
    df[column] = df[column].astype(cat_dtype)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 62410 entries, 0 to 62409
# Data columns (total 13 columns):
# month                    62410 non-null datetime64[ns]
# Year                     62410 non-null object
# Month                    62410 non-null category
# town                     62410 non-null category
# flat_type                62410 non-null category
# storey                   62410 non-null category
# floor_area_sqm           62410 non-null float64
# flat_model               62410 non-null category
# Remaining_lease_years    62410 non-null float64
# Postal_code              62410 non-null object
# num_schools              62410 non-null float64
# school_rank_nearby       62410 non-null category
# resale_price             62410 non-null float64
# dtypes: category(6), datetime64[ns](1), float64(4), object(2)
# memory usage: 6.7+ MB

# %% [markdown]
# Split test train data according to time; Jun to Nov 2019 will be in the test set while Jan 2017 to May 2019 data will be in the training set

# %%
data_test = df[df.month >= datetime.datetime(2019,6,1)] #put this aside until model selection and evaluation
data_train = df[df.month < datetime.datetime(2019,6,1)]

# %%
data_test.to_pickle('data_test.pkl')
data_train.to_pickle('data_train.pkl')

# %%
from sklearn.model_selection import train_test_split
seed = 111

# %%
def treat_features (df):
    columns_to_keep = ['Month','town','flat_type',"flat_model",'storey','floor_area_sqm','Remaining_lease_years','num_schools',"school_rank_nearby"]
    y = pd.Series(df['resale_price'])
    x = pd.DataFrame(df[columns_to_keep])
    categorical_features = ['Month','town','flat_type','storey','school_rank_nearby',"flat_model"]
    X = pd.get_dummies(x,columns = categorical_features,drop_first = True)
    return train_test_split(X,y,test_size = 0.2,random_state = seed)

# %%
X_train,X_test,y_train,y_test = treat_features(data_train)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40422 entries, 50295 to 12116
# Data columns (total 57 columns):
# floor_area_sqm                            40422 non-null float64
# Remaining_lease_years                     40422 non-null float64
# num_schools                               40422 non-null float64
# Month_02                                  40422 non-null uint8
# Month_03                                  40422 non-null uint8
# Month_04                                  40422 non-null uint8
# Month_05                                  40422 non-null uint8
# Month_06                                  40422 non-null uint8
# Month_07                                  40422 non-null uint8
# Month_08                                  40422 non-null uint8
# Month_09                                  40422 non-null uint8
# Month_10                                  40422 non-null uint8
# Month_11                                  40422 non-null uint8
# Month_12                                  40422 non-null uint8
# town_BEDOK                                40422 non-null uint8
# town_BISHAN                               40422 non-null uint8
# town_BUKIT BATOK                          40422 non-null uint8
# town_BUKIT MERAH                          40422 non-null uint8
# town_BUKIT PANJANG                        40422 non-null uint8
# town_BUKIT TIMAH                          40422 non-null uint8
# town_CENTRAL AREA                         40422 non-null uint8
# town_CHOA CHU KANG                        40422 non-null uint8
# town_CLEMENTI                             40422 non-null uint8
# town_GEYLANG                              40422 non-null uint8
# town_HOUGANG                              40422 non-null uint8
# town_JURONG EAST                          40422 non-null uint8
# town_JURONG WEST                          40422 non-null uint8
# town_KALLANG/WHAMPOA                      40422 non-null uint8
# town_MARINE PARADE                        40422 non-null uint8
# town_PASIR RIS                            40422 non-null uint8
# town_PUNGGOL                              40422 non-null uint8
# town_QUEENSTOWN                           40422 non-null uint8
# town_SEMBAWANG                            40422 non-null uint8
# town_SENGKANG                             40422 non-null uint8
# town_SERANGOON                            40422 non-null uint8
# town_TAMPINES                             40422 non-null uint8
# town_TOA PAYOH                            40422 non-null uint8
# town_WOODLANDS                            40422 non-null uint8
# town_YISHUN                               40422 non-null uint8
# flat_type_3 ROOM                          40422 non-null uint8
# flat_type_4 ROOM                          40422 non-null uint8
# flat_type_5 ROOM                          40422 non-null uint8
# flat_type_EXECUTIVE & MULTI-GENERATION    40422 non-null uint8
# storey_0_LowFlr                           40422 non-null uint8
# storey_2_HighFlr                          40422 non-null uint8
# school_rank_nearby_1                      40422 non-null uint8
# school_rank_nearby_2                      40422 non-null uint8
# school_rank_nearby_3                      40422 non-null uint8
# flat_model_New Generation                 40422 non-null uint8
# flat_model_DBSS                           40422 non-null uint8
# flat_model_Standard                       40422 non-null uint8
# flat_model_Apartment                      40422 non-null uint8
# flat_model_Simplified                     40422 non-null uint8
# flat_model_Model A                        40422 non-null uint8
# flat_model_Terrace/Multi-Gen/Adjoined     40422 non-null uint8
# flat_model_Maisonette                     40422 non-null uint8
# flat_model_Type S                         40422 non-null uint8
# dtypes: float64(3), uint8(54)
# memory usage: 3.3 MB

# %% [markdown]
# Ready to start our first model: Ordinary least square model.
#
# It also serves an important purpose to check if the data is proper for linear regression. If not we need to further feature engineered the data

# %%
import statsmodels.api as sm

# %%
X = sm.add_constant(X_train)
X_pred = sm.add_constant(X_test)
# Out:
# C:\Users\Zhiqing\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2542: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
model = sm.OLS(y_train,X)
results = model.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           resale_price   R-squared:                       0.857
# Model:                            OLS   Adj. R-squared:                  0.857
# Method:                 Least Squares   F-statistic:                     4248.
# Date:                Fri, 31 Jan 2020   Prob (F-statistic):               0.00
# Time:                        23:31:36   Log-Likelihood:            -5.0065e+05
# No. Observations:               40422   AIC:                         1.001e+06
# Df Residuals:                   40364   BIC:                         1.002e+06
# Df Model:                          57
# Covariance Type:            nonrobust
# ==========================================================================================================
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# const                                  -2.885e+05   5475.512    -52.693      0.000   -2.99e+05   -2.78e+05
# floor_area_sqm                          3813.8494     50.831     75.030      0.000    3714.219    3913.480
# Remaining_lease_years                   4863.5489     43.929    110.715      0.000    4777.448    4949.650
# num_schools                             1753.8589    152.133     11.528      0.000    1455.674    2052.044
# Month_02                               -2604.8491   1501.906     -1.734      0.083   -5548.620     338.922
# Month_03                                -372.0441   1360.666     -0.273      0.785   -3038.980    2294.892
# Month_04                               -2223.0448   1357.007     -1.638      0.101   -4882.810     436.721
# Month_05                                 -47.6009   1345.542     -0.035      0.972   -2684.893    2589.691
# Month_06                                -452.2257   1487.168     -0.304      0.761   -3367.109    2462.657
# Month_07                                -725.4036   1436.067     -0.505      0.613   -3540.128    2089.321
# Month_08                                  -3.5037   1457.597     -0.002      0.998   -2860.428    2853.420
# Month_09                               -2324.9102   1489.165     -1.561      0.118   -5243.708     593.888
# Month_10                               -1977.2453   1481.178     -1.335      0.182   -4880.388     925.897
# Month_11                                1081.6030   1475.681      0.733      0.464   -1810.766    3973.972
# Month_12                                 370.0217   1569.523      0.236      0.814   -2706.280    3446.323
# town_BEDOK                             -4903.2400   1970.788     -2.488      0.013   -8766.030   -1040.450
# town_BISHAN                             9.843e+04   2580.330     38.145      0.000    9.34e+04    1.03e+05
# town_BUKIT BATOK                       -7.945e+04   2217.480    -35.829      0.000   -8.38e+04   -7.51e+04
# town_BUKIT MERAH                        1.151e+05   2103.282     54.708      0.000    1.11e+05    1.19e+05
# town_BUKIT PANJANG                     -1.331e+05   2467.035    -53.935      0.000   -1.38e+05   -1.28e+05
# town_BUKIT TIMAH                        2.071e+05   5616.229     36.884      0.000    1.96e+05    2.18e+05
# town_CENTRAL AREA                        1.17e+05   4347.675     26.904      0.000    1.08e+05    1.25e+05
# town_CHOA CHU KANG                     -1.677e+05   2361.093    -71.038      0.000   -1.72e+05   -1.63e+05
# town_CLEMENTI                           4.939e+04   2423.317     20.381      0.000    4.46e+04    5.41e+04
# town_GEYLANG                            4.408e+04   2425.625     18.172      0.000    3.93e+04    4.88e+04
# town_HOUGANG                           -8.685e+04   2066.336    -42.030      0.000   -9.09e+04   -8.28e+04
# town_JURONG EAST                       -5.616e+04   2482.631    -22.620      0.000    -6.1e+04   -5.13e+04
# town_JURONG WEST                       -1.334e+05   1871.870    -71.273      0.000   -1.37e+05    -1.3e+05
# town_KALLANG/WHAMPOA                    5.841e+04   2335.736     25.006      0.000    5.38e+04     6.3e+04
# town_MARINE PARADE                      1.665e+05   4029.642     41.319      0.000    1.59e+05    1.74e+05
# town_PASIR RIS                          -1.09e+05   2338.398    -46.616      0.000   -1.14e+05   -1.04e+05
# town_PUNGGOL                           -1.524e+05   2958.951    -51.509      0.000   -1.58e+05   -1.47e+05
# town_QUEENSTOWN                         1.331e+05   2451.162     54.294      0.000    1.28e+05    1.38e+05
# town_SEMBAWANG                         -1.955e+05   2393.559    -81.663      0.000      -2e+05   -1.91e+05
# town_SENGKANG                          -1.615e+05   2477.836    -65.195      0.000   -1.66e+05   -1.57e+05
# town_SERANGOON                         -5056.5054   2482.298     -2.037      0.042   -9921.865    -191.146
# town_TAMPINES                          -5.018e+04   1951.498    -25.715      0.000    -5.4e+04   -4.64e+04
# town_TOA PAYOH                          5.463e+04   2234.092     24.453      0.000    5.03e+04     5.9e+04
# town_WOODLANDS                         -1.716e+05   2021.386    -84.882      0.000   -1.76e+05   -1.68e+05
# town_YISHUN                            -1.095e+05   2039.518    -53.707      0.000   -1.14e+05   -1.06e+05
# flat_type_3 ROOM                        2.607e+04   2829.805      9.213      0.000    2.05e+04    3.16e+04
# flat_type_4 ROOM                        3.795e+04   3545.288     10.704      0.000     3.1e+04    4.49e+04
# flat_type_5 ROOM                        4.612e+04   4643.425      9.932      0.000     3.7e+04    5.52e+04
# flat_type_EXECUTIVE & MULTI-GENERATION  6.881e+04   5596.580     12.295      0.000    5.78e+04    7.98e+04
# storey_0_LowFlr                        -2.264e+04    642.732    -35.225      0.000   -2.39e+04   -2.14e+04
# storey_2_HighFlr                        3.408e+04    870.204     39.162      0.000    3.24e+04    3.58e+04
# school_rank_nearby_1                   -4906.0158    917.127     -5.349      0.000   -6703.606   -3108.426
# school_rank_nearby_2                    5002.8230   1465.994      3.413      0.001    2129.442    7876.204
# school_rank_nearby_3                   -4.395e+04   3389.799    -12.965      0.000   -5.06e+04   -3.73e+04
# flat_model_New Generation                1.74e+04   1297.423     13.411      0.000    1.49e+04    1.99e+04
# flat_model_DBSS                         1.519e+05   2798.732     54.261      0.000    1.46e+05    1.57e+05
# flat_model_Standard                     2.021e+04   2003.107     10.092      0.000    1.63e+04    2.41e+04
# flat_model_Apartment                    7493.3233   1380.333      5.429      0.000    4787.839    1.02e+04
# flat_model_Simplified                    1.36e+04   1788.887      7.601      0.000    1.01e+04    1.71e+04
# flat_model_Model A                     -1804.5562   1281.713     -1.408      0.159   -4316.743     707.631
# flat_model_Terrace/Multi-Gen/Adjoined   1.203e+05   5640.418     21.320      0.000    1.09e+05    1.31e+05
# flat_model_Maisonette                   4.929e+04   2392.021     20.607      0.000    4.46e+04     5.4e+04
# flat_model_Type S                       2.202e+05   6881.682     31.996      0.000    2.07e+05    2.34e+05
# ==============================================================================
# Omnibus:                     3562.230   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5657.572
# Skew:                           0.667   Prob(JB):                         0.00
# Kurtosis:                       4.258   Cond. No.                     3.79e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.79e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
y_pred = results.predict(X_pred)

# %% [markdown]
# ### Assumption check:
# 1. The residuals seem to follow Gaussian assumption while reading skew and kurtosis (Skew = 0.633 and Kurtosis = 4.5). We can try to treat the dependent variable to see if it improves the assumption
#
# 2. Multicollinearity exists as the floor area and the flat flat is correlated; p-value also suggests the similarly. However, we would not remove the flat_type as it is an important consideration for actual buyers
#
# However, we would like to check the residual plots just to make sure that it is reflecting the same

# %%
def diagnostic_plot(y_true,y_pred):
    plt.figure(figsize=(15,6))
    
    plt.subplot(1, 2, 1)
    res = y_true - y_pred
    plt.scatter(y_pred, res)
    plt.title("Residual plot")
    plt.xlabel("prediction")
    plt.ylabel("residuals")
    
    plt.subplot(1, 2, 2)
    stats.probplot(res, dist="norm", plot=plt)
    plt.title("Normal Q-Q plot")

# %%
diagnostic_plot(y_test,y_pred)

# %% [markdown]
# The QQ plot shows a curvy behavior, we need to consider transforming the target variable;
#
# residual plot also show certain pattern which is not ideal

# %% [markdown]
# ### Feature selection:
# -> "Month" proves to be a redundant feature (p-value >0.05) > we will remove it
#
# -> Some features from town seems to be insignificant and so does some school ranking; We will keep it for now
#
# The rest of the features looks significant for the model

# %%
def treat_features_logy (df):
    columns_to_keep = ['town','flat_type','storey','floor_area_sqm','Remaining_lease_years','num_schools',"school_rank_nearby","flat_model"]
    y = pd.Series(df['resale_price'].apply(lambda x: np.log(x)))
    x = pd.DataFrame(df[columns_to_keep])
    categorical_features = ['town','flat_type','storey','school_rank_nearby','flat_model']
    X = pd.get_dummies(x,columns = categorical_features,drop_first = True)
    return train_test_split(X,y,test_size = 0.2,random_state = seed)

# %%
X_train,X_test,y_train,y_test = treat_features_logy(data_train)

# %%
X = sm.add_constant(X_train)
X_pred = sm.add_constant(X_test)
model = sm.OLS(y_train,X)

results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           resale_price   R-squared:                       0.883
# Model:                            OLS   Adj. R-squared:                  0.883
# Method:                 Least Squares   F-statistic:                     6605.
# Date:                Fri, 31 Jan 2020   Prob (F-statistic):               0.00
# Time:                        23:35:56   Log-Likelihood:                 31418.
# No. Observations:               40422   AIC:                        -6.274e+04
# Df Residuals:                   40375   BIC:                        -6.234e+04
# Df Model:                          46
# Covariance Type:            nonrobust
# ==========================================================================================================
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# const                                     11.2345      0.010   1086.496      0.000      11.214      11.255
# floor_area_sqm                             0.0083   9.76e-05     84.710      0.000       0.008       0.008
# Remaining_lease_years                      0.0104   8.43e-05    123.300      0.000       0.010       0.011
# num_schools                                0.0039      0.000     13.256      0.000       0.003       0.004
# town_BEDOK                                -0.0002      0.004     -0.049      0.961      -0.008       0.007
# town_BISHAN                                0.1788      0.005     36.095      0.000       0.169       0.189
# town_BUKIT BATOK                          -0.1699      0.004    -39.897      0.000      -0.178      -0.162
# town_BUKIT MERAH                           0.2261      0.004     55.981      0.000       0.218       0.234
# town_BUKIT PANJANG                        -0.2526      0.005    -53.333      0.000      -0.262      -0.243
# town_BUKIT TIMAH                           0.3714      0.011     34.440      0.000       0.350       0.392
# town_CENTRAL AREA                          0.3116      0.008     37.331      0.000       0.295       0.328
# town_CHOA CHU KANG                        -0.3441      0.005    -75.903      0.000      -0.353      -0.335
# town_CLEMENTI                              0.1095      0.005     23.541      0.000       0.100       0.119
# town_GEYLANG                               0.0818      0.005     17.570      0.000       0.073       0.091
# town_HOUGANG                              -0.1712      0.004    -43.154      0.000      -0.179      -0.163
# town_JURONG EAST                          -0.1095      0.005    -22.978      0.000      -0.119      -0.100
# town_JURONG WEST                          -0.2766      0.004    -76.958      0.000      -0.284      -0.270
# town_KALLANG/WHAMPOA                       0.1305      0.004     29.089      0.000       0.122       0.139
# town_MARINE PARADE                         0.3694      0.008     47.743      0.000       0.354       0.385
# town_PASIR RIS                            -0.2023      0.004    -45.051      0.000      -0.211      -0.193
# town_PUNGGOL                              -0.2748      0.006    -48.369      0.000      -0.286      -0.264
# town_QUEENSTOWN                            0.2673      0.005     56.802      0.000       0.258       0.277
# town_SEMBAWANG                            -0.3999      0.005    -87.025      0.000      -0.409      -0.391
# town_SENGKANG                             -0.3051      0.005    -64.130      0.000      -0.314      -0.296
# town_SERANGOON                            -0.0027      0.005     -0.576      0.565      -0.012       0.007
# town_TAMPINES                             -0.0758      0.004    -20.238      0.000      -0.083      -0.068
# town_TOA PAYOH                             0.0925      0.004     21.572      0.000       0.084       0.101
# town_WOODLANDS                            -0.3604      0.004    -92.865      0.000      -0.368      -0.353
# town_YISHUN                               -0.2334      0.004    -59.607      0.000      -0.241      -0.226
# flat_type_3 ROOM                           0.1590      0.005     29.256      0.000       0.148       0.170
# flat_type_4 ROOM                           0.2353      0.007     34.568      0.000       0.222       0.249
# flat_type_5 ROOM                           0.2450      0.009     27.477      0.000       0.227       0.262
# flat_type_EXECUTIVE & MULTI-GENERATION     0.2689      0.011     25.022      0.000       0.248       0.290
# storey_0_LowFlr                           -0.0542      0.001    -43.895      0.000      -0.057      -0.052
# storey_2_HighFlr                           0.0566      0.002     33.895      0.000       0.053       0.060
# school_rank_nearby_1                      -0.0129      0.002     -7.353      0.000      -0.016      -0.009
# school_rank_nearby_2                      -0.0065      0.003     -2.304      0.021      -0.012      -0.001
# school_rank_nearby_3                      -0.0952      0.007    -14.637      0.000      -0.108      -0.082
# flat_model_New Generation                  0.0384      0.002     15.433      0.000       0.034       0.043
# flat_model_DBSS                            0.1982      0.005     36.882      0.000       0.188       0.209
# flat_model_Standard                        0.0238      0.004      6.177      0.000       0.016       0.031
# flat_model_Apartment                       0.0208      0.003      7.864      0.000       0.016       0.026
# flat_model_Simplified                      0.0187      0.003      5.448      0.000       0.012       0.025
# flat_model_Model A                        -0.0034      0.002     -1.362      0.173      -0.008       0.001
# flat_model_Terrace/Multi-Gen/Adjoined      0.1868      0.011     17.244      0.000       0.166       0.208
# flat_model_Maisonette                      0.0714      0.005     15.547      0.000       0.062       0.080
# flat_model_Type S                          0.1442      0.013     10.915      0.000       0.118       0.170
# ==============================================================================
# Omnibus:                      701.649   Durbin-Watson:                   2.020
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              889.117
# Skew:                           0.246   Prob(JB):                    8.52e-194
# Kurtosis:                       3.534   Cond. No.                     3.78e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.78e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
y_pred = results.predict(X_pred)
diagnostic_plot(y_test,y_pred)
#much better now

# %% [markdown]
# Treating the dependent variable helps to improve the model fitting (R2 from 0.857 to 0.883);
#
# We also observe significant improvement of residual normality assumptions:
# * Residual plot shows a random behavior and constant variance with just a few outliners;
# * QQ plot mainly follows straight line behavior with a right tail; The data set may have a few observation that is quite right skewed
# * Observation also confirmed by improved score of skewness and Kurtosis stats
